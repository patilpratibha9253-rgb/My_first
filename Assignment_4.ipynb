# %% [markdown]
# <a href="https://colab.research.google.com/github/patilpratibha9253-rgb/My_first/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_password_strength(password):
    if len(password) < 8:
        return "Weak Password: Must be at least 8 characters long."

    has_digit = False
    has_special = False
    special_characters = "!@#$%^&*()_+-=[]{}|;:',.<>?/"

    for char in password:
        if char.isdigit():
            has_digit = True
        if char in special_characters:
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    elif not has_digit:
        return "Weak Password: Must contain at least one digit."
    else:
        return "Weak Password: Must contain at least one special character."


# Example function calls
print(check_password_strength("Pass@123"))   # Strong Password
print(check_password_strength("Password"))   # Weak - no digit & special char
print(check_password_strength("Pass1234"))   # Weak - no special char
# Out:
# Strong Password
# Weak Password: Must contain at least one digit.
# Weak Password: Must contain at least one special character.
