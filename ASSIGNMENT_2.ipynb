# %% [markdown]
# <a href="https://colab.research.google.com/github/patilpratibha9253-rgb/My_first/blob/main/ASSIGNMENT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Inventory Reorder Checker

n = int(input("Enter number of products: "))

print("\n--- Inventory Status ---")

for i in range(1, n + 1):
    stock = int(input(f"Enter stock quantity for Product {i}: "))

    if stock < 20:
        print(f"Product {i}: Reorder Required")
    else:
        print(f"Product {i}: Stock Sufficient")
# Out:
# Enter number of products: 4
#
# --- Inventory Status ---
# Enter stock quantity for Product 1: 4500
# Product 1: Stock Sufficient
# Enter stock quantity for Product 2: 6000
# Product 2: Stock Sufficient
# Enter stock quantity for Product 3: 7000
# Product 3: Stock Sufficient
# Enter stock quantity for Product 4: 5000
# Product 4: Stock Sufficient
