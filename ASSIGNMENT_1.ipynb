# %% [markdown]
# <a href="https://colab.research.google.com/github/patilpratibha9253-rgb/My_first/blob/main/ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Daily Sales Aggregator

days = int(input("Enter number of days: "))

total_sales = 0

for i in range(1, days + 1):
    sales = float(input(f"Enter sales for day {i}: "))
    total_sales += sales

average_sales = total_sales / days

print("\n--- Sales Summary ---")
print("Total Sales:", total_sales)
print("Average Sales:", average_sales)
# Out:
# Enter number of days: 12
# Enter sales for day 1: 10000
# Enter sales for day 2: 20000
# Enter sales for day 3: 30000
# Enter sales for day 4: 40000
# Enter sales for day 5: 50000
# Enter sales for day 6: 60000
# Enter sales for day 7: 70000
# Enter sales for day 8: 80000
# Enter sales for day 9: 90000
# Enter sales for day 10: 7200
# Enter sales for day 11: 63000
# Enter sales for day 12: 470000
#
# --- Sales Summary ---
# Total Sales: 990200.0
# Average Sales: 82516.66666666667
