# %% [markdown]
# <a href="https://colab.research.google.com/github/patilpratibha9253-rgb/My_first/blob/main/Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def register_employee():
    emp_id = input("Enter Employee ID: ")
    name = input("Enter Name: ")
    age = int(input("Enter Age: "))
    department = input("Enter Department: ")
    basic_salary = float(input("Enter Basic Salary: "))

    if age < 18:
        print("Error: Employee must be at least 18 years old")
        return None
    if basic_salary <= 0:
        print("Error: Salary must be greater than 0")
        return None

    print("Employee Registered Successfully\n")

    return basic_salary
